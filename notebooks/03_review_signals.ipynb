# %% [markdown]
# # 03 — Review signals by segment
# Use review scores as an interpretation layer after segmentation.

# %%
segments = [
 {'segment':'loyal','mean_review':4.6,'customers':420},
 {'segment':'at_risk','mean_review':3.4,'customers':180}]
[{**s,'review_gap':round(5-s['mean_review'],1)} for s in segments]

# %% [markdown]
# Keeping satisfaction outside the RFM feature set preserves the behavioral meaning of clusters and avoids circular interpretations.
