# %% [markdown]
# # 01 — RFM exploration
# Translate order history into explainable customer features with a fixed analysis date.

# %%
import pandas as pd
from customer_segments.rfm import build_rfm

orders = pd.DataFrame({
 'customer_id':['a','a','b'],
 'order_id':['o1','o2','o3'],
 'order_date':pd.to_datetime(['2024-01-02','2024-02-01','2024-01-20']),
 'payment_value':[30.,45.,20.]})
build_rfm(orders, reference_date='2024-03-01')

# %% [markdown]
# Inspect cancellations, duplicated orders and unusually high spend before modelling. Keep the reference date explicit for reproducibility.
