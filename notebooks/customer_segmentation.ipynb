# %% [markdown]
# # E-commerce Customer Segmentation
# Build deterministic RFM features and explainable clusters from authorized local copies of the public Olist tables.

# %%
from pathlib import Path
import pandas as pd
from customer_segments import build_rfm, cluster_rfm

DATA_DIR = Path('../data/raw')

# %% [markdown]
# ## Prepare an order-level table
# Join customer, order and payment tables using their documented identifiers. Keep only pseudonymous customer IDs and transactional measures needed for RFM.

# %%
# orders = pd.read_csv(DATA_DIR / 'orders_for_rfm.csv')
# rfm = build_rfm(orders, reference_date='2018-10-01')
# segmented = cluster_rfm(rfm, clusters=4)
# segmented.groupby('cluster').mean().round(2)
