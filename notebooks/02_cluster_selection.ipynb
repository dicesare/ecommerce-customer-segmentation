# %% [markdown]
# # 02 — Cluster selection
# Choose a useful segmentation, not merely the lowest inertia.

# %%
candidates = [
 {'k':2,'silhouette':0.42,'business_readability':'low'},
 {'k':3,'silhouette':0.48,'business_readability':'high'},
 {'k':4,'silhouette':0.46,'business_readability':'medium'}]
max(candidates, key=lambda x: (x['business_readability']=='high', x['silhouette']))

# %% [markdown]
# Compare scaled feature distributions, silhouette, segment size and whether each cluster supports a distinct action. Validate robustness across random seeds.
