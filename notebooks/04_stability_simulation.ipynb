# %% [markdown]
# # 04 — Segmentation stability
# Simulate monthly refreshes to distinguish model quality from operational stability.

# %%
monthly = [
 {'month':0,'stable_assignment_rate':1.00},
 {'month':1,'stable_assignment_rate':0.91},
 {'month':2,'stable_assignment_rate':0.83},
 {'month':3,'stable_assignment_rate':0.72}]
next(x for x in monthly if x['stable_assignment_rate'] < .80)

# %% [markdown]
# In production, measure adjusted Rand index or centroid drift on a stable customer cohort, then choose retraining thresholds with the marketing team.
